# %%
import pandas as pd
import requests
import json
from datetime import datetime

# %%
player_full_names = {
    "R. Shawcross": "Ryan Shawcross",
    "L. Dunk": "Lewis Dunk",
    "C. Clark": "Ciaran Clark",
    "S. Duffy": "Shane Duffy",
    "F. Lejeune": "Florian Lejeune",
    "W. Hoedt": "Wesley Hoedt",
    "Ahmed Hegazy": "Ahmed Elsayed Ali Elsayed Hegazy",
    "A. Wan-Bissaka": "Aaron Wan-Bissaka",
    "C. Kabasele": "Christian Kabasele",
    "K. Long": "Kevin Long",
    "C. Smalling": "Chris Smalling",
    "A. Williams": "Ashley Williams",
    "M. Rojo": "Marcos Rojo",
    "S. Mustafi": "Shkodran Mustafi",
    "C. Schindler": "Christopher Schindler",
    "M. Keane": "Michael Keane",
    "J. Tomkins": "James Tomkins",
    "A. Ogbonna": "Angelo Ogbonna",
    "P. Jagielka": "Phil Jagielka",
    "J. Kenny": "Jonjoe Kenny",
    "N. Pareja": "Nicolás Pareja",
    "L. Cabrera": "Leandro Cabrera",
    "Bartra": "Marc Bartra",
    "G. Maripán": "Guillermo Maripán",
    "F. Schär": "Fabian Schär",
    "Jesús Vallejo": "Jesús Vallejo",
    "Djené": "Djené Dakonam",
    "Juan Cala": "Juan Cala",
    "Rúben Vezo": "Rúben Vezo",
    "E. Muñoz": "Ezequiel Muñoz",
    "Z. Feddal": "Zouhair Feddal",
    "J. Murillo": "Jeison Murillo",
    "Luisinho": "Luis Carlos Almeida da Cunha",
    "Bóveda": "Eneko Bóveda Altube",
    "M. Dos Santos": "Mauro Dos Santos",
    "Víctor Ruíz": "Víctor Ruíz",
    "Rodrigo Ely": "Rodrigo Ely",
    "C. Lenglet": "Clément Lenglet",
    "S. Kjær": "Simon Kjær",
    "Muniesa": "Marc Muniesa",
    "P. Lienhart": "Philipp Lienhart",
    "A. Hack": "Alexander Hack",
    "L. Balogun": "Leon Balogun",
    "N. Stark": "Niklas Stark",
    "Felipe": "Felipe",
    "D. Maroh": "Dominique Maroh",
    "S. Bell": "Stefan Bell",
    "M. Gulde": "Manuel Gulde",
    "D. Heintz": "Dominik Heintz",
    "B. Hübner": "Benjamin Hübner",
    "T. Hübers": "Timo Hübers",
    "F. Sørensen": "Frederik Sørensen",
    "K. Papadopoulos": "Kyriakos Papadopoulos",
    "S. Sané": "Salif Sané",
    "J. Elez": "Josip Elez",
    "M. Akanji": "Manuel Akanji",
    "J. Vestergaard": "Jannik Vestergaard",
    "J. Bruma": "Jeffrey Bruma",
    "B. Pavard": "Benjamin Pavard",
    "M. Mavraj": "Mërgim Mavraj",
    "F. Helander": "Filip Helander",
    "F. Ceccherini": "Federico Ceccherini",
    "M. Lemos": "Mauricio Lemos",
    "L. Ceppitelli": "Luca Ceppitelli",
    "N. Spolli": "Nicolas Spolli",
    "L. Cabrera": "Leandro Cabrera", # Duplicate key, keeping the first one found
    "D. Dainelli": "Dario Dainelli",
    "J. Andersen": "Joachim Andersen",
    "B. Djimsiti": "Berat Djimsiti",
    "M. Bani": "Mattia Bani",
    "T. Heurtaux": "Thomas Heurtaux",
    "E. Goldaniga": "Edoardo Goldaniga",
    "G. Pezzella": "Germán Pezzella",
    "T. Cionek": "Thiago Cionek",
    "A. Caracciolo": "Antonio Caracciolo",
    "A. Ferrari": "Alessandro Ferrari",
    "T. Letschert": "Timo Letschert",
    "João Miranda": "João Miranda",
    "A. Izzo": "Armando Izzo",
    "E. Zukanović": "Ervin Zukanović",
    "K. Adénon": "Kassimou Adénon",
    "P. Djilobodji": "Papy Djilobodji",
    "D. Da Silva": "Damien Da Silva",
    "Diego Carlos": "Diego Carlos",
    "P. Gouano": "Prince-Désir Gouano",
    "Edgar Ié": "Edgar Ié",
    "B. Dibassy": "Bakaye Dibassy",
    "M. Debuchy": "Mathieu Debuchy",
    "N. Pallois": "Nicolas Pallois",
    "K. Théophile Catherine": "Kévin Théophile-Catherine",
    "C. Jullien": "Christopher Jullien",
    "I. Cissokho": "Issa Cissokho",
    "K. Mangane": "Kader Mangane",
    "N. Subotić": "Neven Subotić",
    "W. Lautoa": "Wesley Lautoa",
    "C. Kerbrat": "Christophe Kerbrat",
    "J. Koundé": "Jules Koundé",
    "M. Niakhaté": "Mouhamadou Niakhaté",
    "V. Selimovic": "Vojislav Selimović",
    "J. Cordoval": "Jimmy Cordoval"
}

# %%
len(player_full_names)
# Out:
# 99

# %%
def get_player_market_value_history(player_name):
    """
    Fetches the market value history for a given player name using the Transfermarkt API.

    Args:
        player_name (str): The name of the player to search for.

    Returns:
        list: A list of dictionaries, where each dictionary represents an entry
              in the player's market value history, or None if the player
              is not found or an error occurs.
    """
    base_url = "https://transfermarkt-api.fly.dev"

    # Step 1: Get player ID
    # Construct the search URL by replacing spaces in the player's name with '%20'
    search_url = f"{base_url}/players/search/{player_name.replace(' ', '%20')}?page_number=1"
    print(f"Searching for player ID for '{player_name}': {search_url}")
    try:
        # Make the HTTP GET request to the search API
        search_response = requests.get(search_url)
        # Raise an HTTPError for bad responses (4xx or 5xx status codes)
        search_response.raise_for_status()
        # Parse the JSON response
        search_data = search_response.json()
    except requests.exceptions.RequestException as e:
        # Handle network-related errors or bad HTTP responses
        print(f"Error fetching player ID for {player_name}: {e}")
        return None
    except json.JSONDecodeError:
        # Handle errors if the response is not valid JSON
        print(f"Error decoding JSON from player ID search for {player_name}.")
        return None

    # Check if any results were returned
    if not search_data or not search_data.get("results"):
        print(f"Player '{player_name}' not found.")
        return None

    # Assuming the first result is the desired player for simplicity
    player_id = search_data["results"][0]["id"]
    player_found_name = search_data["results"][0]["name"]
    print(f"Found player: {player_found_name} with ID: {player_id}")

    # Step 2: Get market value history
    # Construct the market value URL using the obtained player ID
    market_value_url = f"{base_url}/players/{player_id}/market_value"
    print(f"Fetching market value history for '{player_found_name}': {market_value_url}")
    try:
        # Make the HTTP GET request to the market value API
        market_value_response = requests.get(market_value_url)
        # Raise an HTTPError for bad responses
        market_value_response.raise_for_status()
        # Parse the JSON response
        market_value_data = market_value_response.json()
    except requests.exceptions.RequestException as e:
        # Handle network-related errors or bad HTTP responses
        print(f"Error fetching market value for {player_found_name}: {e}")
        return None
    except json.JSONDecodeError:
        # Handle errors if the response is not valid JSON
        print(f"Error decoding JSON from market value API for {player_found_name}.")
        return None

    # Return the market value history list if available, otherwise None
    return market_value_data.get("marketValueHistory")


def get_multiple_players_market_values(player_names):
    """
    Fetches market value histories for a list of players and compiles them
    into a structured dataset.

    Args:
        player_names (list): A list of player names (strings).

    Returns:
        dict: A dictionary where keys are player names and values are their
              market value histories (list of dicts), or None if not found/error.
              Players not found will have a value of None.
    """
    dataset = {}
    for name in player_names:
        print(f"\n--- Processing {name} ---")
        history = get_player_market_value_history(name)
        dataset[name] = history
    return dataset



# Get the dataset
market_value_dataset = get_multiple_players_market_values([i for i in player_full_names.values()])
# Out:
# --- Processing Ryan Shawcross ---
# Searching for player ID for 'Ryan Shawcross': https://transfermarkt-api.fly.dev/players/search/Ryan%20Shawcross?page_number=1
# Found player: Ryan Shawcross with ID: 45861
# Fetching market value history for 'Ryan Shawcross': https://transfermarkt-api.fly.dev/players/45861/market_value
#
# --- Processing Lewis Dunk ---
# Searching for player ID for 'Lewis Dunk': https://transfermarkt-api.fly.dev/players/search/Lewis%20Dunk?page_number=1
# Found player: Lewis Dunk with ID: 148153
# Fetching market value history for 'Lewis Dunk': https://transfermarkt-api.fly.dev/players/148153/market_value
#
# --- Processing Ciaran Clark ---
# Searching for player ID for 'Ciaran Clark': https://transfermarkt-api.fly.dev/players/search/Ciaran%20Clark?page_number=1
# Found player: Ciaran Clark with ID: 98240
# Fetching market value history for 'Ciaran Clark': https://transfermarkt-api.fly.dev/players/98240/market_value
#
# --- Processing Shane Duffy ---
# Searching for player ID for 'Shane Duffy': https://transfermarkt-api.fly.dev/players/search/Shane%20Duffy?page_number=1
# Found player: Shane Duffy with ID: 119269
# Fetching market value history for 'Shane Duffy': https://transfermarkt-api.fly.dev/players/119269/market_value
#
# --- Processing Florian Lejeune ---
# Searching for player ID for 'Florian Lejeune': https://transfermarkt-api.fly.dev/players/search/Florian%20Lejeune?page_number=1
# Found player: Florian Lejeune with ID: 127108
# Fetching market value history for 'Florian Lejeune': https://transfermarkt-api.fly.dev/players/127108/market_value
#
# --- Processing Wesley Hoedt ---
# Searching for player ID for 'Wesley Hoedt': https://transfermarkt-api.fly.dev/players/search/Wesley%20Hoedt?page_number=1
# Found player: Wesley Hoedt with ID: 253765
# Fetching market value history for 'Wesley Hoedt': https://transfermarkt-api.fly.dev/players/253765/market_value
#
# --- Processing Ahmed Elsayed Ali Elsayed Hegazy ---
# Searching for player ID for 'Ahmed Elsayed Ali Elsayed Hegazy': https://transfermarkt-api.fly.dev/players/search/Ahmed%20Elsayed%20Ali%20Elsayed%20Hegazy?page_number=1
# Player 'Ahmed Elsayed Ali Elsayed Hegazy' not found.
#
# --- Processing Aaron Wan-Bissaka ---
# Searching for player ID for 'Aaron Wan-Bissaka': https://transfermarkt-api.fly.dev/players/search/Aaron%20Wan-Bissaka?page_number=1
# Found player: Aaron Wan-Bissaka with ID: 477758
# Fetching market value history for 'Aaron Wan-Bissaka': https://transfermarkt-api.fly.dev/players/477758/market_value
#
# --- Processing Christian Kabasele ---
# Searching for player ID for 'Christian Kabasele': https://transfermarkt-api.fly.dev/players/search/Christian%20Kabasele?page_number=1
# Found player: Christian Kabasele with ID: 81512
# Fetching market value history for 'Christian Kabasele': https://transfermarkt-api.fly.dev/players/81512/market_value
#
# --- Processing Kevin Long ---
# Searching for player ID for 'Kevin Long': https://transfermarkt-api.fly.dev/players/search/Kevin%20Long?page_number=1
# Found player: Kevin Long with ID: 111114
# Fetching market value history for 'Kevin Long': https://transfermarkt-api.fly.dev/players/111114/market_value
#
# --- Processing Chris Smalling ---
# Searching for player ID for 'Chris Smalling': https://transfermarkt-api.fly.dev/players/search/Chris%20Smalling?page_number=1
# Found player: Chris Smalling with ID: 103427
# Fetching market value history for 'Chris Smalling': https://transfermarkt-api.fly.dev/players/103427/market_value
#
# --- Processing Ashley Williams ---
# Searching for player ID for 'Ashley Williams': https://transfermarkt-api.fly.dev/players/search/Ashley%20Williams?page_number=1
# Found player: Ashley Williams with ID: 67355
# Fetching market value history for 'Ashley Williams': https://transfermarkt-api.fly.dev/players/67355/market_value
#
# --- Processing Marcos Rojo ---
# Searching for player ID for 'Marcos Rojo': https://transfermarkt-api.fly.dev/players/search/Marcos%20Rojo?page_number=1
# Found player: Marcos Rojo with ID: 93176
# Fetching market value history for 'Marcos Rojo': https://transfermarkt-api.fly.dev/players/93176/market_value
#
# --- Processing Shkodran Mustafi ---
# Searching for player ID for 'Shkodran Mustafi': https://transfermarkt-api.fly.dev/players/search/Shkodran%20Mustafi?page_number=1
# Found player: Shkodran Mustafi with ID: 88590
# Fetching market value history for 'Shkodran Mustafi': https://transfermarkt-api.fly.dev/players/88590/market_value
#
# --- Processing Christopher Schindler ---
# Searching for player ID for 'Christopher Schindler': https://transfermarkt-api.fly.dev/players/search/Christopher%20Schindler?page_number=1
# Found player: Christopher Schindler with ID: 57842
# Fetching market value history for 'Christopher Schindler': https://transfermarkt-api.fly.dev/players/57842/market_value
#
# --- Processing Michael Keane ---
# Searching for player ID for 'Michael Keane': https://transfermarkt-api.fly.dev/players/search/Michael%20Keane?page_number=1
# Found player: Michael Keane with ID: 118534
# Fetching market value history for 'Michael Keane': https://transfermarkt-api.fly.dev/players/118534/market_value
#
# --- Processing James Tomkins ---
# Searching for player ID for 'James Tomkins': https://transfermarkt-api.fly.dev/players/search/James%20Tomkins?page_number=1
# Found player: James Tomkins with ID: 61592
# Fetching market value history for 'James Tomkins': https://transfermarkt-api.fly.dev/players/61592/market_value
#
# --- Processing Angelo Ogbonna ---
# Searching for player ID for 'Angelo Ogbonna': https://transfermarkt-api.fly.dev/players/search/Angelo%20Ogbonna?page_number=1
# Found player: Angelo Ogbonna with ID: 48002
# Fetching market value history for 'Angelo Ogbonna': https://transfermarkt-api.fly.dev/players/48002/market_value
#
# --- Processing Phil Jagielka ---
# Searching for player ID for 'Phil Jagielka': https://transfermarkt-api.fly.dev/players/search/Phil%20Jagielka?page_number=1
# Found player: Phil Jagielka with ID: 13520
# Fetching market value history for 'Phil Jagielka': https://transfermarkt-api.fly.dev/players/13520/market_value
#
# --- Processing Jonjoe Kenny ---
# Searching for player ID for 'Jonjoe Kenny': https://transfermarkt-api.fly.dev/players/search/Jonjoe%20Kenny?page_number=1
# Found player: Jonjoe Kenny with ID: 258883
# Fetching market value history for 'Jonjoe Kenny': https://transfermarkt-api.fly.dev/players/258883/market_value
#
# --- Processing Nicolás Pareja ---
# Searching for player ID for 'Nicolás Pareja': https://transfermarkt-api.fly.dev/players/search/Nicolás%20Pareja?page_number=1
# Found player: Nicolás Pareja with ID: 41281
# Fetching market value history for 'Nicolás Pareja': https://transfermarkt-api.fly.dev/players/41281/market_value
#
# --- Processing Leandro Cabrera ---
# Searching for player ID for 'Leandro Cabrera': https://transfermarkt-api.fly.dev/players/search/Leandro%20Cabrera?page_number=1
# Found player: Leandro Cabrera with ID: 102423
# Fetching market value history for 'Leandro Cabrera': https://transfermarkt-api.fly.dev/players/102423/market_value
#
# --- Processing Marc Bartra ---
# Searching for player ID for 'Marc Bartra': https://transfermarkt-api.fly.dev/players/search/Marc%20Bartra?page_number=1
# Found player: Marc Bartra with ID: 99922
# Fetching market value history for 'Marc Bartra': https://transfermarkt-api.fly.dev/players/99922/market_value
#
# --- Processing Guillermo Maripán ---
# Searching for player ID for 'Guillermo Maripán': https://transfermarkt-api.fly.dev/players/search/Guillermo%20Maripán?page_number=1
# Found player: Guillermo Maripán with ID: 249730
# Fetching market value history for 'Guillermo Maripán': https://transfermarkt-api.fly.dev/players/249730/market_value
#
# --- Processing Fabian Schär ---
# Searching for player ID for 'Fabian Schär': https://transfermarkt-api.fly.dev/players/search/Fabian%20Schär?page_number=1
# Found player: Fabian Schär with ID: 135343
# Fetching market value history for 'Fabian Schär': https://transfermarkt-api.fly.dev/players/135343/market_value
#
# --- Processing Jesús Vallejo ---
# Searching for player ID for 'Jesús Vallejo': https://transfermarkt-api.fly.dev/players/search/Jesús%20Vallejo?page_number=1
# Found player: Jesús Vallejo with ID: 251896
# Fetching market value history for 'Jesús Vallejo': https://transfermarkt-api.fly.dev/players/251896/market_value
#
# --- Processing Djené Dakonam ---
# Searching for player ID for 'Djené Dakonam': https://transfermarkt-api.fly.dev/players/search/Djené%20Dakonam?page_number=1
# Found player: Djené with ID: 221150
# Fetching market value history for 'Djené': https://transfermarkt-api.fly.dev/players/221150/market_value
#
# --- Processing Juan Cala ---
# Searching for player ID for 'Juan Cala': https://transfermarkt-api.fly.dev/players/search/Juan%20Cala?page_number=1
# Found player: Juan Cala with ID: 67089
# Fetching market value history for 'Juan Cala': https://transfermarkt-api.fly.dev/players/67089/market_value
#
# --- Processing Rúben Vezo ---
# Searching for player ID for 'Rúben Vezo': https://transfermarkt-api.fly.dev/players/search/Rúben%20Vezo?page_number=1
# Found player: Rúben Vezo with ID: 257851
# Fetching market value history for 'Rúben Vezo': https://transfermarkt-api.fly.dev/players/257851/market_value
#
# --- Processing Ezequiel Muñoz ---
# Searching for player ID for 'Ezequiel Muñoz': https://transfermarkt-api.fly.dev/players/search/Ezequiel%20Muñoz?page_number=1
# Found player: Ezequiel Muñoz with ID: 75127
# Fetching market value history for 'Ezequiel Muñoz': https://transfermarkt-api.fly.dev/players/75127/market_value
#
# --- Processing Zouhair Feddal ---
# Searching for player ID for 'Zouhair Feddal': https://transfermarkt-api.fly.dev/players/search/Zouhair%20Feddal?page_number=1
# Found player: Zouhair Feddal with ID: 129386
# Fetching market value history for 'Zouhair Feddal': https://transfermarkt-api.fly.dev/players/129386/market_value
#
# --- Processing Jeison Murillo ---
# Searching for player ID for 'Jeison Murillo': https://transfermarkt-api.fly.dev/players/search/Jeison%20Murillo?page_number=1
# Found player: Jeison Murillo with ID: 131102
# Fetching market value history for 'Jeison Murillo': https://transfermarkt-api.fly.dev/players/131102/market_value
#
# --- Processing Luis Carlos Almeida da Cunha ---
# Searching for player ID for 'Luis Carlos Almeida da Cunha': https://transfermarkt-api.fly.dev/players/search/Luis%20Carlos%20Almeida%20da%20Cunha?page_number=1
# Found player: Nani with ID: 33706
# Fetching market value history for 'Nani': https://transfermarkt-api.fly.dev/players/33706/market_value
#
# --- Processing Eneko Bóveda Altube ---
# Searching for player ID for 'Eneko Bóveda Altube': https://transfermarkt-api.fly.dev/players/search/Eneko%20Bóveda%20Altube?page_number=1
# Found player: Eneko Bóveda with ID: 89313
# Fetching market value history for 'Eneko Bóveda': https://transfermarkt-api.fly.dev/players/89313/market_value
#
# --- Processing Mauro Dos Santos ---
# Searching for player ID for 'Mauro Dos Santos': https://transfermarkt-api.fly.dev/players/search/Mauro%20Dos%20Santos?page_number=1
# Found player: Mauro dos Santos with ID: 55240
# Fetching market value history for 'Mauro dos Santos': https://transfermarkt-api.fly.dev/players/55240/market_value
#
# --- Processing Víctor Ruíz ---
# Searching for player ID for 'Víctor Ruíz': https://transfermarkt-api.fly.dev/players/search/Víctor%20Ruíz?page_number=1
# Found player: Víctor Ruiz with ID: 62920
# Fetching market value history for 'Víctor Ruiz': https://transfermarkt-api.fly.dev/players/62920/market_value
#
# --- Processing Rodrigo Ely ---
# Searching for player ID for 'Rodrigo Ely': https://transfermarkt-api.fly.dev/players/search/Rodrigo%20Ely?page_number=1
# Found player: Rodrigo Ely with ID: 176140
# Fetching market value history for 'Rodrigo Ely': https://transfermarkt-api.fly.dev/players/176140/market_value
#
# --- Processing Clément Lenglet ---
# Searching for player ID for 'Clément Lenglet': https://transfermarkt-api.fly.dev/players/search/Clément%20Lenglet?page_number=1
# Found player: Clément Lenglet with ID: 182904
# Fetching market value history for 'Clément Lenglet': https://transfermarkt-api.fly.dev/players/182904/market_value
#
# --- Processing Simon Kjær ---
# Searching for player ID for 'Simon Kjær': https://transfermarkt-api.fly.dev/players/search/Simon%20Kjær?page_number=1
# Player 'Simon Kjær' not found.
#
# --- Processing Marc Muniesa ---
# Searching for player ID for 'Marc Muniesa': https://transfermarkt-api.fly.dev/players/search/Marc%20Muniesa?page_number=1
# Found player: Marc Muniesa with ID: 74228
# Fetching market value history for 'Marc Muniesa': https://transfermarkt-api.fly.dev/players/74228/market_value
#
# --- Processing Philipp Lienhart ---
# Searching for player ID for 'Philipp Lienhart': https://transfermarkt-api.fly.dev/players/search/Philipp%20Lienhart?page_number=1
# Found player: Philipp Lienhart with ID: 225657
# Fetching market value history for 'Philipp Lienhart': https://transfermarkt-api.fly.dev/players/225657/market_value
#
# --- Processing Alexander Hack ---
# Searching for player ID for 'Alexander Hack': https://transfermarkt-api.fly.dev/players/search/Alexander%20Hack?page_number=1
# Found player: Alexander Hack with ID: 126281
# Fetching market value history for 'Alexander Hack': https://transfermarkt-api.fly.dev/players/126281/market_value
#
# --- Processing Leon Balogun ---
# Searching for player ID for 'Leon Balogun': https://transfermarkt-api.fly.dev/players/search/Leon%20Balogun?page_number=1
# Found player: Leon Balogun with ID: 56100
# Fetching market value history for 'Leon Balogun': https://transfermarkt-api.fly.dev/players/56100/market_value
#
# --- Processing Niklas Stark ---
# Searching for player ID for 'Niklas Stark': https://transfermarkt-api.fly.dev/players/search/Niklas%20Stark?page_number=1
# Found player: Niklas Stark with ID: 162434
# Fetching market value history for 'Niklas Stark': https://transfermarkt-api.fly.dev/players/162434/market_value
#
# --- Processing Felipe ---
# Searching for player ID for 'Felipe': https://transfermarkt-api.fly.dev/players/search/Felipe?page_number=1
# Found player: Felipe Anderson with ID: 159372
# Fetching market value history for 'Felipe Anderson': https://transfermarkt-api.fly.dev/players/159372/market_value
#
# --- Processing Dominique Maroh ---
# Searching for player ID for 'Dominique Maroh': https://transfermarkt-api.fly.dev/players/search/Dominique%20Maroh?page_number=1
# Player 'Dominique Maroh' not found.
#
# --- Processing Stefan Bell ---
# Searching for player ID for 'Stefan Bell': https://transfermarkt-api.fly.dev/players/search/Stefan%20Bell?page_number=1
# Found player: Stefan Bell with ID: 82350
# Fetching market value history for 'Stefan Bell': https://transfermarkt-api.fly.dev/players/82350/market_value
#
# --- Processing Manuel Gulde ---
# Searching for player ID for 'Manuel Gulde': https://transfermarkt-api.fly.dev/players/search/Manuel%20Gulde?page_number=1
# Found player: Manuel Gulde with ID: 45683
# Fetching market value history for 'Manuel Gulde': https://transfermarkt-api.fly.dev/players/45683/market_value
#
# --- Processing Dominik Heintz ---
# Searching for player ID for 'Dominik Heintz': https://transfermarkt-api.fly.dev/players/search/Dominik%20Heintz?page_number=1
# Player 'Dominik Heintz' not found.
#
# --- Processing Benjamin Hübner ---
# Searching for player ID for 'Benjamin Hübner': https://transfermarkt-api.fly.dev/players/search/Benjamin%20Hübner?page_number=1
# Found player: Benjamin Hübner with ID: 52348
# Fetching market value history for 'Benjamin Hübner': https://transfermarkt-api.fly.dev/players/52348/market_value
#
# --- Processing Timo Hübers ---
# Searching for player ID for 'Timo Hübers': https://transfermarkt-api.fly.dev/players/search/Timo%20Hübers?page_number=1
# Found player: Timo Hübers with ID: 236981
# Fetching market value history for 'Timo Hübers': https://transfermarkt-api.fly.dev/players/236981/market_value
#
# --- Processing Frederik Sørensen ---
# Searching for player ID for 'Frederik Sørensen': https://transfermarkt-api.fly.dev/players/search/Frederik%20Sørensen?page_number=1
# Found player: Frederik Sørensen with ID: 91716
# Fetching market value history for 'Frederik Sørensen': https://transfermarkt-api.fly.dev/players/91716/market_value
#
# --- Processing Kyriakos Papadopoulos ---
# Searching for player ID for 'Kyriakos Papadopoulos': https://transfermarkt-api.fly.dev/players/search/Kyriakos%20Papadopoulos?page_number=1
# Found player: Kyriakos Papadopoulos with ID: 58489
# Fetching market value history for 'Kyriakos Papadopoulos': https://transfermarkt-api.fly.dev/players/58489/market_value
#
# --- Processing Salif Sané ---
# Searching for player ID for 'Salif Sané': https://transfermarkt-api.fly.dev/players/search/Salif%20Sané?page_number=1
# Found player: Salif Sané with ID: 126534
# Fetching market value history for 'Salif Sané': https://transfermarkt-api.fly.dev/players/126534/market_value
#
# --- Processing Josip Elez ---
# Searching for player ID for 'Josip Elez': https://transfermarkt-api.fly.dev/players/search/Josip%20Elez?page_number=1
# Found player: Josip Elez with ID: 179895
# Fetching market value history for 'Josip Elez': https://transfermarkt-api.fly.dev/players/179895/market_value
#
# --- Processing Manuel Akanji ---
# Searching for player ID for 'Manuel Akanji': https://transfermarkt-api.fly.dev/players/search/Manuel%20Akanji?page_number=1
# Found player: Manuel Akanji with ID: 284730
# Fetching market value history for 'Manuel Akanji': https://transfermarkt-api.fly.dev/players/284730/market_value
#
# --- Processing Jannik Vestergaard ---
# Searching for player ID for 'Jannik Vestergaard': https://transfermarkt-api.fly.dev/players/search/Jannik%20Vestergaard?page_number=1
# Found player: Jannik Vestergaard with ID: 99331
# Fetching market value history for 'Jannik Vestergaard': https://transfermarkt-api.fly.dev/players/99331/market_value
#
# --- Processing Jeffrey Bruma ---
# Searching for player ID for 'Jeffrey Bruma': https://transfermarkt-api.fly.dev/players/search/Jeffrey%20Bruma?page_number=1
# Found player: Jeffrey Bruma with ID: 88721
# Fetching market value history for 'Jeffrey Bruma': https://transfermarkt-api.fly.dev/players/88721/market_value
#
# --- Processing Benjamin Pavard ---
# Searching for player ID for 'Benjamin Pavard': https://transfermarkt-api.fly.dev/players/search/Benjamin%20Pavard?page_number=1
# Found player: Benjamin Pavard with ID: 353366
# Fetching market value history for 'Benjamin Pavard': https://transfermarkt-api.fly.dev/players/353366/market_value
#
# --- Processing Mërgim Mavraj ---
# Searching for player ID for 'Mërgim Mavraj': https://transfermarkt-api.fly.dev/players/search/Mërgim%20Mavraj?page_number=1
# Found player: Mergim Mavraj with ID: 38267
# Fetching market value history for 'Mergim Mavraj': https://transfermarkt-api.fly.dev/players/38267/market_value
#
# --- Processing Filip Helander ---
# Searching for player ID for 'Filip Helander': https://transfermarkt-api.fly.dev/players/search/Filip%20Helander?page_number=1
# Found player: Filip Helander with ID: 198067
# Fetching market value history for 'Filip Helander': https://transfermarkt-api.fly.dev/players/198067/market_value
#
# --- Processing Federico Ceccherini ---
# Searching for player ID for 'Federico Ceccherini': https://transfermarkt-api.fly.dev/players/search/Federico%20Ceccherini?page_number=1
# Found player: Federico Ceccherini with ID: 163639
# Fetching market value history for 'Federico Ceccherini': https://transfermarkt-api.fly.dev/players/163639/market_value
#
# --- Processing Mauricio Lemos ---
# Searching for player ID for 'Mauricio Lemos': https://transfermarkt-api.fly.dev/players/search/Mauricio%20Lemos?page_number=1
# Found player: Mauricio Lemos with ID: 303140
# Fetching market value history for 'Mauricio Lemos': https://transfermarkt-api.fly.dev/players/303140/market_value
#
# --- Processing Luca Ceppitelli ---
# Searching for player ID for 'Luca Ceppitelli': https://transfermarkt-api.fly.dev/players/search/Luca%20Ceppitelli?page_number=1
# Found player: Luca Ceppitelli with ID: 102745
# Fetching market value history for 'Luca Ceppitelli': https://transfermarkt-api.fly.dev/players/102745/market_value
#
# --- Processing Nicolas Spolli ---
# Searching for player ID for 'Nicolas Spolli': https://transfermarkt-api.fly.dev/players/search/Nicolas%20Spolli?page_number=1
# Found player: Nicolás Spolli with ID: 51186
# Fetching market value history for 'Nicolás Spolli': https://transfermarkt-api.fly.dev/players/51186/market_value
#
# --- Processing Dario Dainelli ---
# Searching for player ID for 'Dario Dainelli': https://transfermarkt-api.fly.dev/players/search/Dario%20Dainelli?page_number=1
# Found player: Dario Dainelli with ID: 5970
# Fetching market value history for 'Dario Dainelli': https://transfermarkt-api.fly.dev/players/5970/market_value
#
# --- Processing Joachim Andersen ---
# Searching for player ID for 'Joachim Andersen': https://transfermarkt-api.fly.dev/players/search/Joachim%20Andersen?page_number=1
# Found player: Joachim Andersen with ID: 260827
# Fetching market value history for 'Joachim Andersen': https://transfermarkt-api.fly.dev/players/260827/market_value
#
# --- Processing Berat Djimsiti ---
# Searching for player ID for 'Berat Djimsiti': https://transfermarkt-api.fly.dev/players/search/Berat%20Djimsiti?page_number=1
# Found player: Berat Djimsiti with ID: 165513
# Fetching market value history for 'Berat Djimsiti': https://transfermarkt-api.fly.dev/players/165513/market_value
#
# --- Processing Mattia Bani ---
# Searching for player ID for 'Mattia Bani': https://transfermarkt-api.fly.dev/players/search/Mattia%20Bani?page_number=1
# Found player: Mattia Bani with ID: 176139
# Fetching market value history for 'Mattia Bani': https://transfermarkt-api.fly.dev/players/176139/market_value
#
# --- Processing Thomas Heurtaux ---
# Searching for player ID for 'Thomas Heurtaux': https://transfermarkt-api.fly.dev/players/search/Thomas%20Heurtaux?page_number=1
# Found player: Thomas Heurtaux with ID: 109598
# Fetching market value history for 'Thomas Heurtaux': https://transfermarkt-api.fly.dev/players/109598/market_value
#
# --- Processing Edoardo Goldaniga ---
# Searching for player ID for 'Edoardo Goldaniga': https://transfermarkt-api.fly.dev/players/search/Edoardo%20Goldaniga?page_number=1
# Found player: Edoardo Goldaniga with ID: 242940
# Fetching market value history for 'Edoardo Goldaniga': https://transfermarkt-api.fly.dev/players/242940/market_value
#
# --- Processing Germán Pezzella ---
# Searching for player ID for 'Germán Pezzella': https://transfermarkt-api.fly.dev/players/search/Germán%20Pezzella?page_number=1
# Found player: Germán Pezzella with ID: 113133
# Fetching market value history for 'Germán Pezzella': https://transfermarkt-api.fly.dev/players/113133/market_value
#
# --- Processing Thiago Cionek ---
# Searching for player ID for 'Thiago Cionek': https://transfermarkt-api.fly.dev/players/search/Thiago%20Cionek?page_number=1
# Found player: Thiago Cionek with ID: 79510
# Fetching market value history for 'Thiago Cionek': https://transfermarkt-api.fly.dev/players/79510/market_value
#
# --- Processing Antonio Caracciolo ---
# Searching for player ID for 'Antonio Caracciolo': https://transfermarkt-api.fly.dev/players/search/Antonio%20Caracciolo?page_number=1
# Found player: Andrea Caracciolo with ID: 6098
# Fetching market value history for 'Andrea Caracciolo': https://transfermarkt-api.fly.dev/players/6098/market_value
#
# --- Processing Alessandro Ferrari ---
# Searching for player ID for 'Alessandro Ferrari': https://transfermarkt-api.fly.dev/players/search/Alessandro%20Ferrari?page_number=1
# Found player: Nico Ferrari with ID: 451627
# Fetching market value history for 'Nico Ferrari': https://transfermarkt-api.fly.dev/players/451627/market_value
#
# --- Processing Timo Letschert ---
# Searching for player ID for 'Timo Letschert': https://transfermarkt-api.fly.dev/players/search/Timo%20Letschert?page_number=1
# Found player: Timo Letschert with ID: 231378
# Fetching market value history for 'Timo Letschert': https://transfermarkt-api.fly.dev/players/231378/market_value
#
# --- Processing João Miranda ---
# Searching for player ID for 'João Miranda': https://transfermarkt-api.fly.dev/players/search/João%20Miranda?page_number=1
# Found player: Miranda with ID: 33357
# Fetching market value history for 'Miranda': https://transfermarkt-api.fly.dev/players/33357/market_value
#
# --- Processing Armando Izzo ---
# Searching for player ID for 'Armando Izzo': https://transfermarkt-api.fly.dev/players/search/Armando%20Izzo?page_number=1
# Found player: Armando Izzo with ID: 32113
# Fetching market value history for 'Armando Izzo': https://transfermarkt-api.fly.dev/players/32113/market_value
#
# --- Processing Ervin Zukanović ---
# Searching for player ID for 'Ervin Zukanović': https://transfermarkt-api.fly.dev/players/search/Ervin%20Zukanović?page_number=1
# Found player: Ervin Zukanovic with ID: 44059
# Fetching market value history for 'Ervin Zukanovic': https://transfermarkt-api.fly.dev/players/44059/market_value
#
# --- Processing Kassimou Adénon ---
# Searching for player ID for 'Kassimou Adénon': https://transfermarkt-api.fly.dev/players/search/Kassimou%20Adénon?page_number=1
# Player 'Kassimou Adénon' not found.
#
# --- Processing Papy Djilobodji ---
# Searching for player ID for 'Papy Djilobodji': https://transfermarkt-api.fly.dev/players/search/Papy%20Djilobodji?page_number=1
# Found player: Papy Djilobodji with ID: 136610
# Fetching market value history for 'Papy Djilobodji': https://transfermarkt-api.fly.dev/players/136610/market_value
#
# --- Processing Damien Da Silva ---
# Searching for player ID for 'Damien Da Silva': https://transfermarkt-api.fly.dev/players/search/Damien%20Da%20Silva?page_number=1
# Found player: Damien Da Silva with ID: 57370
# Fetching market value history for 'Damien Da Silva': https://transfermarkt-api.fly.dev/players/57370/market_value
#
# --- Processing Diego Carlos ---
# Searching for player ID for 'Diego Carlos': https://transfermarkt-api.fly.dev/players/search/Diego%20Carlos?page_number=1
# Found player: Diego Carlos with ID: 329145
# Fetching market value history for 'Diego Carlos': https://transfermarkt-api.fly.dev/players/329145/market_value
#
# --- Processing Prince-Désir Gouano ---
# Searching for player ID for 'Prince-Désir Gouano': https://transfermarkt-api.fly.dev/players/search/Prince-Désir%20Gouano?page_number=1
# Found player: Prince Gouano with ID: 171410
# Fetching market value history for 'Prince Gouano': https://transfermarkt-api.fly.dev/players/171410/market_value
#
# --- Processing Edgar Ié ---
# Searching for player ID for 'Edgar Ié': https://transfermarkt-api.fly.dev/players/search/Edgar%20Ié?page_number=1
# Found player: Edgar Ié with ID: 191987
# Fetching market value history for 'Edgar Ié': https://transfermarkt-api.fly.dev/players/191987/market_value
#
# --- Processing Bakaye Dibassy ---
# Searching for player ID for 'Bakaye Dibassy': https://transfermarkt-api.fly.dev/players/search/Bakaye%20Dibassy?page_number=1
# Found player: Bakaye Dibassy with ID: 410059
# Fetching market value history for 'Bakaye Dibassy': https://transfermarkt-api.fly.dev/players/410059/market_value
#
# --- Processing Mathieu Debuchy ---
# Searching for player ID for 'Mathieu Debuchy': https://transfermarkt-api.fly.dev/players/search/Mathieu%20Debuchy?page_number=1
# Found player: Mathieu Debuchy with ID: 27306
# Fetching market value history for 'Mathieu Debuchy': https://transfermarkt-api.fly.dev/players/27306/market_value
#
# --- Processing Nicolas Pallois ---
# Searching for player ID for 'Nicolas Pallois': https://transfermarkt-api.fly.dev/players/search/Nicolas%20Pallois?page_number=1
# Found player: Nicolas Pallois with ID: 139279
# Fetching market value history for 'Nicolas Pallois': https://transfermarkt-api.fly.dev/players/139279/market_value
#
# --- Processing Kévin Théophile-Catherine ---
# Searching for player ID for 'Kévin Théophile-Catherine': https://transfermarkt-api.fly.dev/players/search/Kévin%20Théophile-Catherine?page_number=1
# Found player: Kévin Théophile-Catherine with ID: 60603
# Fetching market value history for 'Kévin Théophile-Catherine': https://transfermarkt-api.fly.dev/players/60603/market_value
#
# --- Processing Christopher Jullien ---
# Searching for player ID for 'Christopher Jullien': https://transfermarkt-api.fly.dev/players/search/Christopher%20Jullien?page_number=1
# Found player: Christopher Jullien with ID: 201737
# Fetching market value history for 'Christopher Jullien': https://transfermarkt-api.fly.dev/players/201737/market_value
#
# --- Processing Issa Cissokho ---
# Searching for player ID for 'Issa Cissokho': https://transfermarkt-api.fly.dev/players/search/Issa%20Cissokho?page_number=1
# Found player: Issa Cissokho with ID: 183494
# Fetching market value history for 'Issa Cissokho': https://transfermarkt-api.fly.dev/players/183494/market_value
#
# --- Processing Kader Mangane ---
# Searching for player ID for 'Kader Mangane': https://transfermarkt-api.fly.dev/players/search/Kader%20Mangane?page_number=1
# Found player: Kader Mangane with ID: 4796
# Fetching market value history for 'Kader Mangane': https://transfermarkt-api.fly.dev/players/4796/market_value
#
# --- Processing Neven Subotić ---
# Searching for player ID for 'Neven Subotić': https://transfermarkt-api.fly.dev/players/search/Neven%20Subotić?page_number=1
# Found player: Neven Subotic with ID: 40995
# Fetching market value history for 'Neven Subotic': https://transfermarkt-api.fly.dev/players/40995/market_value
#
# --- Processing Wesley Lautoa ---
# Searching for player ID for 'Wesley Lautoa': https://transfermarkt-api.fly.dev/players/search/Wesley%20Lautoa?page_number=1
# Found player: Wesley Lautoa with ID: 154199
# Fetching market value history for 'Wesley Lautoa': https://transfermarkt-api.fly.dev/players/154199/market_value
#
# --- Processing Christophe Kerbrat ---
# Searching for player ID for 'Christophe Kerbrat': https://transfermarkt-api.fly.dev/players/search/Christophe%20Kerbrat?page_number=1
# Found player: Christophe Kerbrat with ID: 138049
# Fetching market value history for 'Christophe Kerbrat': https://transfermarkt-api.fly.dev/players/138049/market_value
#
# --- Processing Jules Koundé ---
# Searching for player ID for 'Jules Koundé': https://transfermarkt-api.fly.dev/players/search/Jules%20Koundé?page_number=1
# Found player: Jules Koundé with ID: 411975
# Fetching market value history for 'Jules Koundé': https://transfermarkt-api.fly.dev/players/411975/market_value
#
# --- Processing Mouhamadou Niakhaté ---
# Searching for player ID for 'Mouhamadou Niakhaté': https://transfermarkt-api.fly.dev/players/search/Mouhamadou%20Niakhaté?page_number=1
# Player 'Mouhamadou Niakhaté' not found.
#
# --- Processing Vojislav Selimović ---
# Searching for player ID for 'Vojislav Selimović': https://transfermarkt-api.fly.dev/players/search/Vojislav%20Selimović?page_number=1
# Player 'Vojislav Selimović' not found.
#
# --- Processing Jimmy Cordoval ---
# Searching for player ID for 'Jimmy Cordoval': https://transfermarkt-api.fly.dev/players/search/Jimmy%20Cordoval?page_number=1
# Player 'Jimmy Cordoval' not found.

# %%
def analyze_market_value_changes(market_value_dataset, end_of_2017_18_season_date_str="2018-06-30"):
    """
    Analyzes the market value changes for each player in the dataset.
    Specifically, it finds the market value at the end of the 2017/2018 season,
    their age at that time, and the highest value achieved after that date.

    Args:
        market_value_dataset (dict): The dataset of player market value histories.
        end_of_2017_18_season_date_str (str): The cutoff date for the end of the 2017/2018 season (YYYY-MM-DD).

    Returns:
        dict: A dictionary containing analysis results for each player.
              Each player's entry will include:
              - 'value_end_2017_18_season': Market value at or just before the cutoff date.
              - 'age_end_2017_18_season': Player's age at or just before the cutoff date.
              - 'highest_value_after': Highest market value after the cutoff date.
              - 'difference': The difference between the highest_value_after and value_end_2017_18_season.
    """
    analysis_results = {}
    cutoff_date = datetime.strptime(end_of_2017_18_season_date_str, "%Y-%m-%d")

    for player_name, history in market_value_dataset.items():
        value_at_season_end = None
        age_at_season_end = None # New variable for age
        highest_value_after = None

        if not history:
            analysis_results[player_name] = {
                'value_end_2017_18_season': None,
                'age_end_2017_18_season': None, # Initialize new age field
                'highest_value_after': None,
                'difference': None,
                'status': 'No history data'
            }
            continue

        # Find the market value and age at or just before the end of the 2017/2018 season
        # We iterate to find the latest value before or on the cutoff date
        for entry in history:
            entry_date = datetime.strptime(entry["date"], "%Y-%m-%d")
            if entry_date <= cutoff_date:
                value_at_season_end = entry.get("marketValue")
                age_at_season_end = entry.get("age") # Capture age
            else:
                # Once we pass the cutoff date, we can break as history is chronological
                break

        # Find the highest market value after the end of the 2017/2018 season
        current_highest_after = 0
        found_value_after_cutoff = False
        for entry in history:
            entry_date = datetime.strptime(entry["date"], "%Y-%m-%d")
            if entry_date > cutoff_date:
                market_value = entry.get("marketValue")
                if isinstance(market_value, (int, float)):
                    if highest_value_after is None or market_value > highest_value_after:
                        highest_value_after = market_value
                    found_value_after_cutoff = True

        difference = None
        status = 'Analyzed'
        if value_at_season_end is not None and highest_value_after is not None:
            difference = highest_value_after - value_at_season_end
        elif value_at_season_end is None:
            status = 'No value found at end of 2017/18 season'
        elif highest_value_after is None:
            status = 'No highest value found after 2017/18 season'

        analysis_results[player_name] = {
            'value_end_2017_18_season': value_at_season_end,
            'age_end_2017_18_season': age_at_season_end, # Include age in results
            'highest_value_after': highest_value_after,
            'difference': difference,
            'status': status
        }
    return analysis_results

# %%
# Perform the analysis
market_value_analysis = analyze_market_value_changes(market_value_dataset)

# %%
df_market_value = pd.DataFrame(market_value_analysis).T

# %%
def format_value(value):
    if value is None:
        return "N/A"
    if isinstance(value, (int, float)):
        if value >= 1_000_000:
            return f"€{value / 1_000_000:.1f}m"
        elif value >= 1_000:
            return f"€{value / 1_000:.1f}k"
        else:
            return f"€{value}"
    return str(value)

df_market_value['difference_formatted'] = df_market_value['difference'].apply(format_value)

# %%
df_market_value.sort_values(by='difference', ascending=False, inplace=True)

# %%
pd.set_option('display.max_rows', None)

# %%
df_market_value[df_market_value['age_end_2017_18_season'] <= 28].head()
# Out:
#                   value_end_2017_18_season age_end_2017_18_season  \
# Jules Koundé                       7000000                     19
# Diego Carlos                      10000000                     25
# Aaron Wan-Bissaka                  1000000                     20
# Clément Lenglet                   25000000                     22
# Joachim Andersen                   1500000                     22
#
#                   highest_value_after difference    status  \
# Jules Koundé                 65000000   58000000  Analyzed
# Diego Carlos                 50000000   40000000  Analyzed
# Aaron Wan-Bissaka            40000000   39000000  Analyzed
# Clément Lenglet              60000000   35000000  Analyzed
# Joachim Andersen             35000000   33500000  Analyzed
#
#                   difference_formatted rank_of_DCI_in_league
# Jules Koundé                    €58.0m                    17
# Diego Carlos                    €40.0m                     4
# Aaron Wan-Bissaka               €39.0m                     8
# Clément Lenglet                 €35.0m                    18
# Joachim Andersen                €33.5m                     8

# %%
countries = ['England', 'Spain', 'Germany', 'Italy', 'France']
rank_of_DCI_in_league = []


for country in countries:
    country_df = pd.read_csv(f'defensive_summaries/{country}_defensive_summary.csv')
    # Function to decode JSON Unicode escape sequences like \u00e9 to é
    def fix_unicode_escape(s):
        try:
            # Decode Unicode escape sequences (like \u00e9 -> é)
            return s.encode('utf-8').decode('unicode_escape')
        except (UnicodeEncodeError, UnicodeDecodeError):
            # If something goes wrong, return the string as is
            return s

    # Apply the fix to the 'name' list
    country_df['name'] = [
        fix_unicode_escape(x) if isinstance(x, str) else x for x in country_df['name']
    ]

    country_df['team'] = [
        fix_unicode_escape(x) if isinstance(x, str) else x for x in country_df['team']
    ]
    final_df = country_df[country_df['total_time'] > 200].sort_values(by='new_DCI_per_90', ascending=False).head(20).reset_index(drop=True)

    #display(final_df)
    display(final_df[['team','name']])

    for row in final_df.iterrows():
        rank_of_DCI_in_league.append({
            'name': player_full_names[row[1]['name']],
            'rank': row[0] + 1
        })
# Out:
#                       team            name
# 0               Stoke City    R. Shawcross
# 1   Brighton & Hove Albion         L. Dunk
# 2         Newcastle United        C. Clark
# 3   Brighton & Hove Albion        S. Duffy
# 4         Newcastle United      F. Lejeune
# 5              Southampton        W. Hoedt
# 6     West Bromwich Albion    Ahmed Hegazy
# 7           Crystal Palace  A. Wan-Bissaka
# 8                  Watford     C. Kabasele
# 9                  Burnley         K. Long
# 10       Manchester United     C. Smalling
# 11                 Everton     A. Williams
# 12       Manchester United         M. Rojo
# 13                 Arsenal      S. Mustafi
# 14       Huddersfield Town    C. Schindler
# 15                 Everton        M. Keane
# 16          Crystal Palace      J. Tomkins
# 17         West Ham United      A. Ogbonna
# 18                 Everton     P. Jagielka
# 19                 Everton        J. Kenny
#                    team           name
# 0               Sevilla      N. Pareja
# 1                Getafe     L. Cabrera
# 2            Real Betis         Bartra
# 3      Deportivo Alavés     G. Maripán
# 4   Deportivo La Coruña       F. Schär
# 5           Real Madrid  Jesús Vallejo
# 6                Getafe          Djené
# 7                Getafe      Juan Cala
# 8              Valencia     Rúben Vezo
# 9               Leganés       E. Muñoz
# 10           Real Betis      Z. Feddal
# 11             Valencia     J. Murillo
# 12  Deportivo La Coruña       Luisinho
# 13  Deportivo La Coruña         Bóveda
# 14              Leganés  M. Dos Santos
# 15           Villarreal    Víctor Ruíz
# 16     Deportivo Alavés    Rodrigo Ely
# 17              Sevilla     C. Lenglet
# 18              Sevilla        S. Kjær
# 19               Girona        Muniesa
#                    team             name
# 0              Freiburg      P. Lienhart
# 1              Mainz 05          A. Hack
# 2              Mainz 05       L. Balogun
# 3            Hertha BSC         N. Stark
# 4           Hannover 96           Felipe
# 5                  Köln         D. Maroh
# 6              Mainz 05          S. Bell
# 7              Freiburg         M. Gulde
# 8                  Köln        D. Heintz
# 9            Hoffenheim        B. Hübner
# 10          Hannover 96        T. Hübers
# 11                 Köln      F. Sørensen
# 12         Hamburger SV  K. Papadopoulos
# 13          Hannover 96          S. Sané
# 14          Hannover 96          J. Elez
# 15    Borussia Dortmund        M. Akanji
# 16  Borussia M'gladbach   J. Vestergaard
# 17            Wolfsburg         J. Bruma
# 18            Stuttgart        B. Pavard
# 19         Hamburger SV        M. Mavraj
#               team           name
# 0          Bologna    F. Helander
# 1          Crotone  F. Ceccherini
# 2         Sassuolo       M. Lemos
# 3         Cagliari  L. Ceppitelli
# 4            Genoa      N. Spolli
# 5          Crotone     L. Cabrera
# 6           Chievo    D. Dainelli
# 7        Sampdoria    J. Andersen
# 8        Benevento    B. Djimsiti
# 9           Chievo        M. Bani
# 10   Hellas Verona    T. Heurtaux
# 11        Sassuolo   E. Goldaniga
# 12      Fiorentina    G. Pezzella
# 13            SPAL      T. Cionek
# 14   Hellas Verona  A. Caracciolo
# 15   Hellas Verona     A. Ferrari
# 16        Sassuolo   T. Letschert
# 17  Internazionale   João Miranda
# 18           Genoa        A. Izzo
# 19           Genoa   E. Zukanović
#              team                    name
# 0       Amiens SC               K. Adénon
# 1           Dijon           P. Djilobodji
# 2            Caen             D. Da Silva
# 3          Nantes            Diego Carlos
# 4       Amiens SC               P. Gouano
# 5           Lille                Edgar Ié
# 6       Amiens SC              B. Dibassy
# 7   Saint-Étienne              M. Debuchy
# 8          Nantes              N. Pallois
# 9   Saint-Étienne  K. Théophile Catherine
# 10       Toulouse              C. Jullien
# 11      Amiens SC             I. Cissokho
# 12     Strasbourg              K. Mangane
# 13  Saint-Étienne              N. Subotić
# 14          Dijon               W. Lautoa
# 15       Guingamp              C. Kerbrat
# 16       Bordeaux               J. Koundé
# 17           Metz             M. Niakhaté
# 18           Metz            V. Selimovic
# 19         Troyes             J. Cordoval

# %%
df_market_value['rank_of_DCI_in_league'] = None

# %%
# add rank of DCI in league to df_market_value
for row in rank_of_DCI_in_league:
    player_name = row['name']
    rank = row['rank']
    if player_name in df_market_value.index:
        df_market_value.at[player_name, 'rank_of_DCI_in_league'] = rank

# %%
under_28 = df_market_value[df_market_value['age_end_2017_18_season'] <= 28]

# %%
print(f'Average expected profit from a randomly selected player younger than 29: {format_value(under_28["difference"].mean())}')

print(f'Chance of making a profit from a randomly selected player younger than 29: {sum(under_28["difference"] > 0) / len(under_28):.2%}')

print(f'Chance of at least breaking even (not losing value) from a randomly selected player younger than 29: {sum(under_28["difference"] >= 0) / len(under_28):.2%}')
# Out:
# Average expected profit from a randomly selected player younger than 29: €7.3m
# Chance of making a profit from a randomly selected player younger than 29: 65.08%
# Chance of at least breaking even (not losing value) from a randomly selected player younger than 29: 87.30%
